# %%
# !pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 56 kB 4.8 MB/s
# ...

# %%
from pytube import YouTube
from pytube import Playlist

# %%
### 경로, url
# download_path = './video'
url = 'https://www.youtube.com/watch?v=TlRNYEAbL50'

### YouTube객체
video = YouTube(url)

# %%
### 유튜브 영상 정보

# print(yt)
# print("제목 : ", yt.title)
# print("길이 : ", yt.length)
# print("게시자 : ", yt.author)
# print("게시날짜 : ", yt.publish_date)
# print("조회수 : ", yt.views)
# print("키워드 : ", yt.keywords)
# print("설명 : ", yt.description)
# print("썸네일 : ", yt.thumbnail_url)
# 등.. yt.으로 확인

# %%
### 동영상/오디오 다운로드

stream = video.streams.get_highest_resolution()
# stream = video.streams.get_audio_only()

# stream.download(download_path)
stream.download()
# Out:
# '/content/Wonder Boy (가을과 겨울이 만났다).mp4'

# %%
### 플레이리스트 다운로드

p = Playlist('https://www.youtube.com/playlist?list=OLAK5uy_mlGWQQxPeVOIWdVQpq4DzOl7jE6hyrkOY')

for video in p.videos:
    stream = video.streams.get_by_resolution('720p')
    # stream = video.streams.get_audio_only()

    # stream.download(download_path)
    stream.download()
